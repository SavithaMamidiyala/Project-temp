# %%
import pandas as pd
import dask.dataframe as dd

# %%
variable = pd.read_csv("/Users/savitha/Desktop/PythonPractice/projectdata/PATIENTS.csv")
#variable.dtypes

# %%
variable1 = pd.read_csv("/Users/savitha/Desktop/PythonPractice/projectdata/LABEVENTS.csv")
#variable1.dtypes

# %%
variable2 = pd.read_csv("/Users/savitha/Desktop/PythonPractice/projectdata/PROCEDURES_ICD.csv")
#variable2.dtypes

# %%
variable3 = pd.read_csv("/Users/savitha/Desktop/PythonPractice/projectdata/PRESCRIPTIONS.csv")
#variable3.dtypes
# Out:
# /Users/savitha/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
variable4 = pd.read_csv("/Users/savitha/Desktop/PythonPractice/projectdata/DIAGNOSES_ICD.csv")
#variable4.dtypes

# %%
variable5 = pd.read_csv("/Users/savitha/Desktop/PythonPractice/projectdata/D_LABITEMS.csv")
#variable5.dtypes

# %%
variable6 = pd.read_csv("/Users/savitha/Desktop/PythonPractice/projectdata/ADMISSIONS.csv")
#variable6.dtypes

# %%
variable7 = pd.read_csv("/Users/savitha/Desktop/PythonPractice/projectdata/CALLOUT.csv")
#variable7.dtypes

# %%
variable8 = pd.read_csv("/Users/savitha/Desktop/PythonPractice/projectdata/INPUTEVENTS_MV.csv")
#variable8.dtypes

# %%
variable9 = pd.read_csv("/Users/savitha/Desktop/PythonPractice/projectdata/TRANSFERS.csv")
#variable9.dtypes

# %%
variable1.count()
# Out:
# ROW_ID        27854055
# SUBJECT_ID    27854055
# HADM_ID       22245034
# ITEMID        27854055
# CHARTTIME     27854055
# VALUE         27852810
# VALUENUM      24932835
# VALUEUOM      24753806
# FLAG           9844166
# dtype: int64

# %%
variable1.dtypes
# Out:
# ROW_ID          int64
# SUBJECT_ID      int64
# HADM_ID       float64
# ITEMID          int64
# CHARTTIME      object
# VALUE          object
# VALUENUM      float64
# VALUEUOM       object
# FLAG           object
# dtype: object

# %%
df = pd.DataFrame(variable1)

# %%
#changing the datatype of HADM_ID from float to int
df['HADM_ID'] = df.HADM_ID.fillna(0).astype(int)

# %%
variable1.dtypes
# Out:
# ROW_ID          int64
# SUBJECT_ID      int64
# HADM_ID         int64
# ITEMID          int64
# CHARTTIME      object
# VALUE          object
# VALUENUM      float64
# VALUEUOM       object
# FLAG           object
# dtype: object

# %%
num_lab_proc_variable = df.groupby(['SUBJECT_ID','HADM_ID'])['ITEMID'].count().reset_index(name='num_lab_procedures')
num_lab_proc_variable.head()
# Out:
#    SUBJECT_ID  HADM_ID  num_lab_procedures
# 0           2   163353                  47
# 1           3        0                 656
# 2           3   145834                1060
# 3           4        0                1409
# 4           4   185777                 245

# %%
#df.HADM_ID.value_counts().reset_index(name='num_lab_procedures')

# %%
#df.groupby(["HADM_ID"]).count().sort_values(["ITEMID"], 
 #   ascending=False).rename(columns={"ITEMID" : "num_lab_procedures"}).reset_index()

# %%
df1 = pd.DataFrame(variable2)

# %%
num_proc_varible = df1.groupby(['SUBJECT_ID','HADM_ID'])['ICD9_CODE'].count().reset_index(name='num_procedures')
num_proc_varible.head()
# Out:
#    SUBJECT_ID  HADM_ID  num_procedures
# 0           2   163353               1
# 1           3   145834               6
# 2           4   185777               3
# 3           5   178980               1
# 4           6   107064               5

# %%
variable3.head()
# Out:
#     ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID            STARTDATE  \
# 0  2214776           6   107064         NaN  2175-06-11 00:00:00
# 1  2214775           6   107064         NaN  2175-06-11 00:00:00
# 2  2215524           6   107064         NaN  2175-06-11 00:00:00
# 3  2216265           6   107064         NaN  2175-06-11 00:00:00
# 4  2214773           6   107064         NaN  2175-06-11 00:00:00
#
#                ENDDATE DRUG_TYPE            DRUG DRUG_NAME_POE  \
# 0  2175-06-12 00:00:00      MAIN      Tacrolimus    Tacrolimus
# 1  2175-06-12 00:00:00      MAIN        Warfarin      Warfarin
# 2  2175-06-12 00:00:00      MAIN  Heparin Sodium           NaN
# 3  2175-06-12 00:00:00      BASE             D5W           NaN
# 4  2175-06-12 00:00:00      MAIN      Furosemide    Furosemide
#
#   DRUG_NAME_GENERIC FORMULARY_DRUG_CD     GSN          NDC  \
# 0        Tacrolimus             TACR1  021796  469061711.0
# 1          Warfarin             WARF5  006562   56017275.0
# 2               NaN        HEPAPREMIX  006522  338055002.0
# 3               NaN           HEPBASE     NaN          0.0
# 4        Furosemide            FURO20  008208   54829725.0
#
#             PROD_STRENGTH DOSE_VAL_RX DOSE_UNIT_RX FORM_VAL_DISP  \
# 0             1mg Capsule           2           mg             2
# 1              5mg Tablet           5           mg             1
# 2  25,000 unit Premix Bag      25,000         UNIT             1
# 3            HEPARIN BASE         250           ml           250
# 4             20mg Tablet          20           mg             1
#
#   FORM_UNIT_DISP ROUTE
# 0            CAP    PO
# 1            TAB    PO
# 2            BAG    IV
# 3             ml    IV
# 4            TAB    PO

# %%
df2 = pd.DataFrame(variable3)

# %%
num_med_variable = df2.groupby(['SUBJECT_ID','HADM_ID'])['DRUG'].count().reset_index(name='num_medications')
num_med_variable.head()
# Out:
#    SUBJECT_ID  HADM_ID  num_medications
# 0           2   163353                4
# 1           4   185777               59
# 2           6   107064              148
# 3           8   159514                4
# 4           9   150750               68

# %%
df3 = pd.DataFrame(variable4)

# %%
number_diag_variable = df3.groupby('SUBJECT_ID')['ICD9_CODE'].count().reset_index(name='number_diagnoses')
number_diag_variable.head()
# Out:
#    SUBJECT_ID  number_diagnoses
# 0           2                 3
# 1           3                 9
# 2           4                 9
# 3           5                 3
# 4           6                 8

# %%
df4 = pd.DataFrame(variable5)

# %%
glu = variable5[variable5.LABEL == 'Glucose']
glu.head()
# Out:
# /Users/savitha/anaconda3/lib/python3.7/site-packages/dask/dataframe/core.py:4382: UserWarning: Insufficient elements for `head`. 5 elements requested, only 3 elements available. Try passing larger `npartitions` to `head`.
#   warnings.warn(msg.format(n, len(r)))
#      ROW_ID  ITEMID    LABEL  FLUID    CATEGORY LOINC_CODE
# 136      10   50809  Glucose  Blood   Blood Gas     2339-0
# 258     132   50931  Glucose  Blood   Chemistry     2345-7
# 677     678   51478  Glucose  Urine  Hematology     5792-7

# %%
variable5.dtypes
# Out:
# ROW_ID         int64
# ITEMID         int64
# LABEL         object
# FLUID         object
# CATEGORY      object
# LOINC_CODE    object
# dtype: object

# %%
#Finding max_glu_serum itemid
glu = df4[df4.LABEL == 'Glucose']
glu_blood = glu[glu.FLUID == 'Blood']
glu_blood_gas = glu_blood[glu_blood.CATEGORY == 'Blood Gas']
df_glu_blood_gas = pd.DataFrame(glu_blood_gas)
#max_glu_serum_variable = df.HADM_ID[df.ITEMID == glu_blood_gas].reset_index(name='number_diagnoses')
#max_glu_serum_variable.head()

# %%
glu_blood_gas.dtypes
# Out:
# ROW_ID         int64
# ITEMID         int64
# LABEL         object
# FLUID         object
# CATEGORY      object
# LOINC_CODE    object
# dtype: object

# %%
variable1.dtypes
# Out:
# ROW_ID          int64
# SUBJECT_ID      int64
# HADM_ID         int64
# ITEMID          int64
# CHARTTIME      object
# VALUE          object
# VALUENUM      float64
# VALUEUOM       object
# FLAG           object
# dtype: object

# %%
#Finding max_glu_serum's itemid from D_LABITEMS in LABEVENTS and fetching HADM_ID
max_glu_serum_temp = df[df['ITEMID'] == int(df_glu_blood_gas['ITEMID'])]
#max_glu_serum_temp.head()
max_glu_serum_temp = max_glu_serum_temp.drop_duplicates(subset=['SUBJECT_ID','HADM_ID'])
#max_glu_serum_temp.head()
max_glu_serum_variable = max_glu_serum_temp.loc[:,['SUBJECT_ID','HADM_ID','ITEMID']]
max_glu_serum_variable.rename(columns={'ITEMID':'max_glu_serum'}, inplace=True)
#max_glu_serum_variable.columns
max_glu_serum_variable.head()
# Out:
#       SUBJECT_ID  HADM_ID  max_glu_serum
# 465            3   145834          50809
# 777            3        0          50809
# 1000           4        0          50809
# 3979           6   107064          50809
# 4380           9   150750          50809

# %%
#Finding A1Cresult itemid
A1Cresult = df4[df4.LABEL == '% Hemoglobin A1c']
df_A1Cresult = pd.DataFrame(A1Cresult)
#df_A1Cresult.head()

# %%
A1Cresult_temp = df[df['ITEMID'] == int(df_A1Cresult['ITEMID'])]
#A1Cresult_temp
A1Cresult_temp = A1Cresult_temp.drop_duplicates(subset=['SUBJECT_ID','HADM_ID'])
#max_glu_serum_temp.head()
A1Cresult_variable = A1Cresult_temp.loc[:,['SUBJECT_ID','HADM_ID','ITEMID']]
A1Cresult_variable.rename(columns={'ITEMID':'A1Cresult'}, inplace=True)
A1Cresult_variable.head()
# Out:
#        SUBJECT_ID  HADM_ID  A1Cresult
# 2494            4        0      50852
# 4409            9   150750      50852
# 7931           17        0      50852
# 8533           18        0      50852
# 10311          23        0      50852

# %%
#Finding glyburide drug from prescriptions.csv
glyburide = df2[df2.DRUG.str.lower() == 'glyburide']
#glyburide.head()
df_glyburide = pd.DataFrame(glyburide.loc[:,['HADM_ID','DRUG']])
df_glyburide.rename(columns={'DRUG':'GlyBURIDE'}, inplace=True)
df_glyburide.head()
# Out:
#        HADM_ID  GlyBURIDE
# 1153    166707  GlyBURIDE
# 1188    166707  GlyBURIDE
# 10561   138528  Glyburide
# 13726   136614  GlyBURIDE
# 18033   135807  Glyburide

# %%
#Finding metformin drug from prescriptions.csv
metformin = df2[df2.DRUG.str.lower() == 'metformin']
#metformin.head()
df_metformin = pd.DataFrame(metformin.loc[:,['HADM_ID','DRUG']])
df_metformin.rename(columns={'DRUG':'Metformin'}, inplace=True)
df_metformin.head()
# Out:
#        HADM_ID  Metformin
# 482     143045  Metformin
# 2744    190665  Metformin
# 9768    151583  Metformin
# 10434   151583  Metformin
# 16448   127976  Metformin

# %%
#Finding pioglitazone drug from prescriptions.csv
pioglitazone = df2[df2.DRUG.str.lower() == 'pioglitazone']
#pioglitazone.head()
df_pioglitazone = pd.DataFrame(pioglitazone.loc[:,['HADM_ID','DRUG']])
df_pioglitazone.rename(columns={'DRUG':'pioglitazone'}, inplace=True)
df_pioglitazone.head()
# Out:
#          HADM_ID  pioglitazone
# 288968    143224  Pioglitazone
# 290186    143224  Pioglitazone
# 290868    143224  Pioglitazone
# 589697    181880  Pioglitazone
# 1174274   114978  Pioglitazone

# %%
#Finding rosiglitazone drug from prescriptions.csv
rosiglitazone = df2[df2.DRUG.str.lower() == 'rosiglitazone maleate']
#rosiglitazone.head()
df_rosiglitazone = pd.DataFrame(rosiglitazone.loc[:,['HADM_ID','DRUG']])
df_rosiglitazone.rename(columns={'DRUG':'rosiglitazone'}, inplace=True)
df_rosiglitazone.head()
# Out:
#        HADM_ID          rosiglitazone
# 24426   162308  Rosiglitazone Maleate
# 34284   116665  Rosiglitazone Maleate
# 39119   116665  Rosiglitazone Maleate
# 39316   116665  Rosiglitazone Maleate
# 47628   130310  Rosiglitazone Maleate

# %%
#Finding insulin drug from prescriptions.csv
insulin = df2[df2.DRUG.str.lower() == 'insulin']
#insulin.head()
df_insulin = pd.DataFrame(insulin.loc[:,['HADM_ID','DRUG']])
df_insulin.rename(columns={'DRUG':'insulin'}, inplace=True)
df_insulin.head()
# Out:
#      HADM_ID  insulin
# 27    143045  Insulin
# 112   185777  Insulin
# 114   185777  Insulin
# 121   185777  Insulin
# 123   185777  Insulin

# %%
#Finding glyburide-metformin drug from prescriptions.csv
#df_glyburide_metformin = df_glyburide[df_glyburide['HADM_ID'] == df_metformin['HADM_ID']]
#df_glyburide_metformin.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-168-282946b243cb> in <module>
#       1 #Finding glyburide-metformin drug from prescriptions.csv
# ----> 2 df_glyburide_metformin = df_glyburide[df_glyburide['HADM_ID'] == df_metformin['HADM_ID']]
#       3 df_glyburide_metformin.head()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1188
#    1189         elif isinstance(other, ABCSeries) and not self._indexed_same(other):
# -> 1190             raise ValueError("Can only compare identically-labeled "
#    1191                              "Series objects")
#    1192
#
# ValueError: Can only compare identically-labeled Series objects

# %%
df_glyburide.dtypes
# Out:
# HADM_ID       int64
# GlyBURIDE    object
# dtype: object

# %%
df_metformin.dtypes
# Out:
# HADM_ID       int64
# Metformin    object
# dtype: object

# %%
#Finding patientweight from inputevents_mv.csv
mrg6 = variable8.loc[:,['HADM_ID','PATIENTWEIGHT']]
#mrg6.head()

# %%
#Finding timeinhospital(LengthOfStay) from transfers.csv
mrg8 = variable9.loc[:,['HADM_ID','LOS']]
#mrg8.head()

# %%
mrg1 = variable6.loc[:,['SUBJECT_ID','HADM_ID','ETHNICITY','ADMISSION_TYPE','ADMISSION_LOCATION',
                        'INSURANCE','DIAGNOSIS','HOSPITAL_EXPIRE_FLAG']]
#mrg1.head()
mrg2 = variable7.loc[:,['HADM_ID','DISCHARGE_WARDID']]
#mrg2.head()
mrg3 = mrg1.merge(mrg2, on='HADM_ID', how='left')
df_mrg = pd.DataFrame(mrg3)
#df_mrg['SUBJECT_ID'] = df_mrg.SUBJECT_ID.fillna(0).astype(int)
#df_mrg['HADM_ID'] = df_mrg.HADM_ID.fillna(0).astype(int)
#df_mrg.dtypes
mrg4 = variable.loc[:,['SUBJECT_ID','GENDER']]
#mrg4.head()
mrg5 = mrg3.merge(mrg4, on='SUBJECT_ID', how='left')
#mrg5.dtypes

# %%
mrg7 = mrg5.merge(mrg6, on='HADM_ID', how='left')
#mrg7
mrg9 = mrg7.merge(mrg8, on='HADM_ID', how='left')
#mrg9
mrg10 = mrg9.merge(num_lab_proc_variable, on = ['SUBJECT_ID','HADM_ID'], how='left')
#mrg10.head()
mrg11 = mrg10.merge(num_proc_varible, on = ['SUBJECT_ID','HADM_ID'], how='left')
#mrg11.head()
mrg12 = mrg11.merge(num_med_variable, on = ['SUBJECT_ID','HADM_ID'], how='left')
#mrg12.head()
mrg13 = mrg12.merge(number_diag_variable, on='SUBJECT_ID', how='left')
#mrg13.head()
mrg14 = mrg13.merge(max_glu_serum_variable, on = ['SUBJECT_ID','HADM_ID'], how='right')
#mrg14

# %%
mrg15 = mrg14.merge(A1Cresult_variable, on = ['SUBJECT_ID','HADM_ID'], how='left')
mrg16 = mrg15.merge(df_metformin, on = 'HADM_ID', how='left')
#mrg16.count()

# %%
mrg17 = mrg16.merge(df_glyburide, on = 'HADM_ID', how='left')
mrg17.count()
# Out:
# SUBJECT_ID              22716972
# HADM_ID                 22716972
# ETHNICITY               22715134
# ADMISSION_TYPE          22715134
# ADMISSION_LOCATION      22715134
# INSURANCE               22715134
# DIAGNOSIS               22715133
# HOSPITAL_EXPIRE_FLAG    22715134
# DISCHARGE_WARDID        16118372
# GENDER                  22715134
# PATIENTWEIGHT           22620063
# LOS                     18999950
# num_lab_procedures      22715134
# num_procedures          22585956
# num_medications         22703022
# number_diagnoses        22715134
# max_glu_serum           22716972
# A1Cresult                5313197
# Metformin                   9936
# GlyBURIDE                 775001
# dtype: int64

# %%
mrg18 = mrg17.merge(df_pioglitazone, on = 'HADM_ID', how='left')
mrg18
# Out:
#           SUBJECT_ID  HADM_ID ETHNICITY ADMISSION_TYPE  \
# 0                 23   152223     WHITE       ELECTIVE
# 1                 23   152223     WHITE       ELECTIVE
# 2                 23   152223     WHITE       ELECTIVE
# 3                 23   152223     WHITE       ELECTIVE
# 4                 23   124321     WHITE      EMERGENCY
# 5                 23   124321     WHITE      EMERGENCY
# 6                 23   124321     WHITE      EMERGENCY
# 7                 23   124321     WHITE      EMERGENCY
# 8                 23   124321     WHITE      EMERGENCY
# 9                 23   124321     WHITE      EMERGENCY
# 10                23   124321     WHITE      EMERGENCY
# 11                23   124321     WHITE      EMERGENCY
# 12                23   124321     WHITE      EMERGENCY
# 13                23   124321     WHITE      EMERGENCY
# 14                23   124321     WHITE      EMERGENCY
# 15                23   124321     WHITE      EMERGENCY
# 16                23   124321     WHITE      EMERGENCY
# 17                23   124321     WHITE      EMERGENCY
# 18                23   124321     WHITE      EMERGENCY
# 19                23   124321     WHITE      EMERGENCY
# 20                23   124321     WHITE      EMERGENCY
# 21                23   124321     WHITE      EMERGENCY
# 22                23   124321     WHITE      EMERGENCY
# 23                23   124321     WHITE      EMERGENCY
# 24                23   124321     WHITE      EMERGENCY
# 25                23   124321     WHITE      EMERGENCY
# 26                23   124321     WHITE      EMERGENCY
# 27                23   124321     WHITE      EMERGENCY
# 28                23   124321     WHITE      EMERGENCY
# 29                23   124321     WHITE      EMERGENCY
# ...              ...      ...       ...            ...
# 22771741       94609        0       NaN            NaN
# 22771742       93235        0       NaN            NaN
# 22771743       93113        0       NaN            NaN
# 22771744       93391        0       NaN            NaN
# 22771745       93949        0       NaN            NaN
# 22771746       93679        0       NaN            NaN
# 22771747       93894        0       NaN            NaN
# 22771748       91000        0       NaN            NaN
# 22771749       93705        0       NaN            NaN
# 22771750       93800        0       NaN            NaN
# 22771751       93732        0       NaN            NaN
# 22771752       93459        0       NaN            NaN
# 22771753       93411        0       NaN            NaN
# 22771754       91379        0       NaN            NaN
# 22771755       98468        0       NaN            NaN
# 22771756       95834        0       NaN            NaN
# 22771757       98297        0       NaN            NaN
# 22771758       98494        0       NaN            NaN
# 22771759       98283        0       NaN            NaN
# 22771760       96115        0       NaN            NaN
# 22771761       97518        0       NaN            NaN
# 22771762       96514        0       NaN            NaN
# 22771763       96913        0       NaN            NaN
# 22771764       96997        0       NaN            NaN
# 22771765       96347        0       NaN            NaN
# 22771766       96892        0       NaN            NaN
# 22771767       96865        0       NaN            NaN
# 22771768       96930        0       NaN            NaN
# 22771769       95798        0       NaN            NaN
# 22771770       99164        0       NaN            NaN
#
#                  ADMISSION_LOCATION INSURANCE  \
# 0         PHYS REFERRAL/NORMAL DELI  Medicare
# 1         PHYS REFERRAL/NORMAL DELI  Medicare
# 2         PHYS REFERRAL/NORMAL DELI  Medicare
# 3         PHYS REFERRAL/NORMAL DELI  Medicare
# 4         TRANSFER FROM HOSP/EXTRAM  Medicare
# 5         TRANSFER FROM HOSP/EXTRAM  Medicare
# 6         TRANSFER FROM HOSP/EXTRAM  Medicare
# 7         TRANSFER FROM HOSP/EXTRAM  Medicare
# 8         TRANSFER FROM HOSP/EXTRAM  Medicare
# 9         TRANSFER FROM HOSP/EXTRAM  Medicare
# 10        TRANSFER FROM HOSP/EXTRAM  Medicare
# 11        TRANSFER FROM HOSP/EXTRAM  Medicare
# 12        TRANSFER FROM HOSP/EXTRAM  Medicare
# 13        TRANSFER FROM HOSP/EXTRAM  Medicare
# 14        TRANSFER FROM HOSP/EXTRAM  Medicare
# 15        TRANSFER FROM HOSP/EXTRAM  Medicare
# 16        TRANSFER FROM HOSP/EXTRAM  Medicare
# 17        TRANSFER FROM HOSP/EXTRAM  Medicare
# 18        TRANSFER FROM HOSP/EXTRAM  Medicare
# 19        TRANSFER FROM HOSP/EXTRAM  Medicare
# 20        TRANSFER FROM HOSP/EXTRAM  Medicare
# 21        TRANSFER FROM HOSP/EXTRAM  Medicare
# 22        TRANSFER FROM HOSP/EXTRAM  Medicare
# 23        TRANSFER FROM HOSP/EXTRAM  Medicare
# 24        TRANSFER FROM HOSP/EXTRAM  Medicare
# 25        TRANSFER FROM HOSP/EXTRAM  Medicare
# 26        TRANSFER FROM HOSP/EXTRAM  Medicare
# 27        TRANSFER FROM HOSP/EXTRAM  Medicare
# 28        TRANSFER FROM HOSP/EXTRAM  Medicare
# 29        TRANSFER FROM HOSP/EXTRAM  Medicare
# ...                             ...       ...
# 22771741                        NaN       NaN
# 22771742                        NaN       NaN
# 22771743                        NaN       NaN
# 22771744                        NaN       NaN
# 22771745                        NaN       NaN
# 22771746                        NaN       NaN
# 22771747                        NaN       NaN
# 22771748                        NaN       NaN
# 22771749                        NaN       NaN
# 22771750                        NaN       NaN
# 22771751                        NaN       NaN
# 22771752                        NaN       NaN
# 22771753                        NaN       NaN
# 22771754                        NaN       NaN
# 22771755                        NaN       NaN
# 22771756                        NaN       NaN
# 22771757                        NaN       NaN
# 22771758                        NaN       NaN
# 22771759                        NaN       NaN
# 22771760                        NaN       NaN
# 22771761                        NaN       NaN
# 22771762                        NaN       NaN
# 22771763                        NaN       NaN
# 22771764                        NaN       NaN
# 22771765                        NaN       NaN
# 22771766                        NaN       NaN
# 22771767                        NaN       NaN
# 22771768                        NaN       NaN
# 22771769                        NaN       NaN
# 22771770                        NaN       NaN
#
#                                                   DIAGNOSIS  \
# 0         CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS...
# 1         CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS...
# 2         CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS...
# 3         CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS...
# 4                                                BRAIN MASS
# 5                                                BRAIN MASS
# 6                                                BRAIN MASS
# 7                                                BRAIN MASS
# 8                                                BRAIN MASS
# 9                                                BRAIN MASS
# 10                                               BRAIN MASS
# 11                                               BRAIN MASS
# 12                                               BRAIN MASS
# 13                                               BRAIN MASS
# 14                                               BRAIN MASS
# 15                                               BRAIN MASS
# 16                                               BRAIN MASS
# 17                                               BRAIN MASS
# 18                                               BRAIN MASS
# 19                                               BRAIN MASS
# 20                                               BRAIN MASS
# 21                                               BRAIN MASS
# 22                                               BRAIN MASS
# 23                                               BRAIN MASS
# 24                                               BRAIN MASS
# 25                                               BRAIN MASS
# 26                                               BRAIN MASS
# 27                                               BRAIN MASS
# 28                                               BRAIN MASS
# 29                                               BRAIN MASS
# ...                                                     ...
# 22771741                                                NaN
# 22771742                                                NaN
# 22771743                                                NaN
# 22771744                                                NaN
# 22771745                                                NaN
# 22771746                                                NaN
# 22771747                                                NaN
# 22771748                                                NaN
# 22771749                                                NaN
# 22771750                                                NaN
# 22771751                                                NaN
# 22771752                                                NaN
# 22771753                                                NaN
# 22771754                                                NaN
# 22771755                                                NaN
# 22771756                                                NaN
# 22771757                                                NaN
# 22771758                                                NaN
# 22771759                                                NaN
# 22771760                                                NaN
# 22771761                                                NaN
# 22771762                                                NaN
# 22771763                                                NaN
# 22771764                                                NaN
# 22771765                                                NaN
# 22771766                                                NaN
# 22771767                                                NaN
# 22771768                                                NaN
# 22771769                                                NaN
# 22771770                                                NaN
#
#           HOSPITAL_EXPIRE_FLAG  DISCHARGE_WARDID GENDER     ...         LOS  \
# 0                          0.0               NaN      M     ...        9.29
# 1                          0.0               NaN      M     ...       30.34
# 2                          0.0               NaN      M     ...       99.15
# 3                          0.0               NaN      M     ...         NaN
# 4                          0.0              31.0      M     ...       64.09
# 5                          0.0              31.0      M     ...       28.47
# 6                          0.0              31.0      M     ...        5.95
# 7                          0.0              31.0      M     ...       63.97
# 8                          0.0              31.0      M     ...         NaN
# 9                          0.0              31.0      M     ...       64.09
# 10                         0.0              31.0      M     ...       28.47
# 11                         0.0              31.0      M     ...        5.95
# 12                         0.0              31.0      M     ...       63.97
# 13                         0.0              31.0      M     ...         NaN
# 14                         0.0              31.0      M     ...       64.09
# 15                         0.0              31.0      M     ...       28.47
# 16                         0.0              31.0      M     ...        5.95
# 17                         0.0              31.0      M     ...       63.97
# 18                         0.0              31.0      M     ...         NaN
# 19                         0.0              31.0      M     ...       64.09
# 20                         0.0              31.0      M     ...       28.47
# 21                         0.0              31.0      M     ...        5.95
# 22                         0.0              31.0      M     ...       63.97
# 23                         0.0              31.0      M     ...         NaN
# 24                         0.0              31.0      M     ...       64.09
# 25                         0.0              31.0      M     ...       28.47
# 26                         0.0              31.0      M     ...        5.95
# 27                         0.0              31.0      M     ...       63.97
# 28                         0.0              31.0      M     ...         NaN
# 29                         0.0              31.0      M     ...       64.09
# ...                        ...               ...    ...     ...         ...
# 22771741                   NaN               NaN    NaN     ...         NaN
# 22771742                   NaN               NaN    NaN     ...         NaN
# 22771743                   NaN               NaN    NaN     ...         NaN
# 22771744                   NaN               NaN    NaN     ...         NaN
# 22771745                   NaN               NaN    NaN     ...         NaN
# 22771746                   NaN               NaN    NaN     ...         NaN
# 22771747                   NaN               NaN    NaN     ...         NaN
# 22771748                   NaN               NaN    NaN     ...         NaN
# 22771749                   NaN               NaN    NaN     ...         NaN
# 22771750                   NaN               NaN    NaN     ...         NaN
# 22771751                   NaN               NaN    NaN     ...         NaN
# 22771752                   NaN               NaN    NaN     ...         NaN
# 22771753                   NaN               NaN    NaN     ...         NaN
# 22771754                   NaN               NaN    NaN     ...         NaN
# 22771755                   NaN               NaN    NaN     ...         NaN
# 22771756                   NaN               NaN    NaN     ...         NaN
# 22771757                   NaN               NaN    NaN     ...         NaN
# 22771758                   NaN               NaN    NaN     ...         NaN
# 22771759                   NaN               NaN    NaN     ...         NaN
# 22771760                   NaN               NaN    NaN     ...         NaN
# 22771761                   NaN               NaN    NaN     ...         NaN
# 22771762                   NaN               NaN    NaN     ...         NaN
# 22771763                   NaN               NaN    NaN     ...         NaN
# 22771764                   NaN               NaN    NaN     ...         NaN
# 22771765                   NaN               NaN    NaN     ...         NaN
# 22771766                   NaN               NaN    NaN     ...         NaN
# 22771767                   NaN               NaN    NaN     ...         NaN
# 22771768                   NaN               NaN    NaN     ...         NaN
# 22771769                   NaN               NaN    NaN     ...         NaN
# 22771770                   NaN               NaN    NaN     ...         NaN
#
#           num_lab_procedures  num_procedures  num_medications  \
# 0                      208.0             7.0             69.0
# 1                      208.0             7.0             69.0
# 2                      208.0             7.0             69.0
# 3                      208.0             7.0             69.0
# 4                      221.0             1.0             69.0
# 5                      221.0             1.0             69.0
# 6                      221.0             1.0             69.0
# 7                      221.0             1.0             69.0
# 8                      221.0             1.0             69.0
# 9                      221.0             1.0             69.0
# 10                     221.0             1.0             69.0
# 11                     221.0             1.0             69.0
# 12                     221.0             1.0             69.0
# 13                     221.0             1.0             69.0
# 14                     221.0             1.0             69.0
# 15                     221.0             1.0             69.0
# 16                     221.0             1.0             69.0
# 17                     221.0             1.0             69.0
# 18                     221.0             1.0             69.0
# 19                     221.0             1.0             69.0
# 20                     221.0             1.0             69.0
# 21                     221.0             1.0             69.0
# 22                     221.0             1.0             69.0
# 23                     221.0             1.0             69.0
# 24                     221.0             1.0             69.0
# 25                     221.0             1.0             69.0
# 26                     221.0             1.0             69.0
# 27                     221.0             1.0             69.0
# 28                     221.0             1.0             69.0
# 29                     221.0             1.0             69.0
# ...                      ...             ...              ...
# 22771741                 NaN             NaN              NaN
# 22771742                 NaN             NaN              NaN
# 22771743                 NaN             NaN              NaN
# 22771744                 NaN             NaN              NaN
# 22771745                 NaN             NaN              NaN
# 22771746                 NaN             NaN              NaN
# 22771747                 NaN             NaN              NaN
# 22771748                 NaN             NaN              NaN
# 22771749                 NaN             NaN              NaN
# 22771750                 NaN             NaN              NaN
# 22771751                 NaN             NaN              NaN
# 22771752                 NaN             NaN              NaN
# 22771753                 NaN             NaN              NaN
# 22771754                 NaN             NaN              NaN
# 22771755                 NaN             NaN              NaN
# 22771756                 NaN             NaN              NaN
# 22771757                 NaN             NaN              NaN
# 22771758                 NaN             NaN              NaN
# 22771759                 NaN             NaN              NaN
# 22771760                 NaN             NaN              NaN
# 22771761                 NaN             NaN              NaN
# 22771762                 NaN             NaN              NaN
# 22771763                 NaN             NaN              NaN
# 22771764                 NaN             NaN              NaN
# 22771765                 NaN             NaN              NaN
# 22771766                 NaN             NaN              NaN
# 22771767                 NaN             NaN              NaN
# 22771768                 NaN             NaN              NaN
# 22771769                 NaN             NaN              NaN
# 22771770                 NaN             NaN              NaN
#
#           number_diagnoses  max_glu_serum  A1Cresult  Metformin GlyBURIDE  \
# 0                     18.0          50809        NaN        NaN       NaN
# 1                     18.0          50809        NaN        NaN       NaN
# 2                     18.0          50809        NaN        NaN       NaN
# 3                     18.0          50809        NaN        NaN       NaN
# 4                     18.0          50809        NaN        NaN       NaN
# 5                     18.0          50809        NaN        NaN       NaN
# 6                     18.0          50809        NaN        NaN       NaN
# 7                     18.0          50809        NaN        NaN       NaN
# 8                     18.0          50809        NaN        NaN       NaN
# 9                     18.0          50809        NaN        NaN       NaN
# 10                    18.0          50809        NaN        NaN       NaN
# 11                    18.0          50809        NaN        NaN       NaN
# 12                    18.0          50809        NaN        NaN       NaN
# 13                    18.0          50809        NaN        NaN       NaN
# 14                    18.0          50809        NaN        NaN       NaN
# 15                    18.0          50809        NaN        NaN       NaN
# 16                    18.0          50809        NaN        NaN       NaN
# 17                    18.0          50809        NaN        NaN       NaN
# 18                    18.0          50809        NaN        NaN       NaN
# 19                    18.0          50809        NaN        NaN       NaN
# 20                    18.0          50809        NaN        NaN       NaN
# 21                    18.0          50809        NaN        NaN       NaN
# 22                    18.0          50809        NaN        NaN       NaN
# 23                    18.0          50809        NaN        NaN       NaN
# 24                    18.0          50809        NaN        NaN       NaN
# 25                    18.0          50809        NaN        NaN       NaN
# 26                    18.0          50809        NaN        NaN       NaN
# 27                    18.0          50809        NaN        NaN       NaN
# 28                    18.0          50809        NaN        NaN       NaN
# 29                    18.0          50809        NaN        NaN       NaN
# ...                    ...            ...        ...        ...       ...
# 22771741               NaN          50809        NaN        NaN       NaN
# 22771742               NaN          50809        NaN        NaN       NaN
# 22771743               NaN          50809    50852.0        NaN       NaN
# 22771744               NaN          50809        NaN        NaN       NaN
# 22771745               NaN          50809        NaN        NaN       NaN
# 22771746               NaN          50809    50852.0        NaN       NaN
# 22771747               NaN          50809    50852.0        NaN       NaN
# 22771748               NaN          50809        NaN        NaN       NaN
# 22771749               NaN          50809        NaN        NaN       NaN
# 22771750               NaN          50809        NaN        NaN       NaN
# 22771751               NaN          50809        NaN        NaN       NaN
# 22771752               NaN          50809    50852.0        NaN       NaN
# 22771753               NaN          50809        NaN        NaN       NaN
# 22771754               NaN          50809    50852.0        NaN       NaN
# 22771755               NaN          50809        NaN        NaN       NaN
# 22771756               NaN          50809        NaN        NaN       NaN
# 22771757               NaN          50809        NaN        NaN       NaN
# 22771758               NaN          50809        NaN        NaN       NaN
# 22771759               NaN          50809    50852.0        NaN       NaN
# 22771760               NaN          50809        NaN        NaN       NaN
# 22771761               NaN          50809        NaN        NaN       NaN
# 22771762               NaN          50809        NaN        NaN       NaN
# 22771763               NaN          50809        NaN        NaN       NaN
# 22771764               NaN          50809    50852.0        NaN       NaN
# 22771765               NaN          50809        NaN        NaN       NaN
# 22771766               NaN          50809        NaN        NaN       NaN
# 22771767               NaN          50809        NaN        NaN       NaN
# 22771768               NaN          50809    50852.0        NaN       NaN
# 22771769               NaN          50809    50852.0        NaN       NaN
# 22771770               NaN          50809        NaN        NaN       NaN
#
#          pioglitazone
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# ...               ...
# 22771741          NaN
# 22771742          NaN
# 22771743          NaN
# 22771744          NaN
# 22771745          NaN
# 22771746          NaN
# 22771747          NaN
# 22771748          NaN
# 22771749          NaN
# 22771750          NaN
# 22771751          NaN
# 22771752          NaN
# 22771753          NaN
# 22771754          NaN
# 22771755          NaN
# 22771756          NaN
# 22771757          NaN
# 22771758          NaN
# 22771759          NaN
# 22771760          NaN
# 22771761          NaN
# 22771762          NaN
# 22771763          NaN
# 22771764          NaN
# 22771765          NaN
# 22771766          NaN
# 22771767          NaN
# 22771768          NaN
# 22771769          NaN
# 22771770          NaN
#
# [22771771 rows x 21 columns]

# %%
#mrg19 = mrg18.merge(df_rosiglitazone, on = 'HADM_ID', how='left')
#mrg19.count()

# %%
#mrg20 = mrg19.merge(df_insulin, on = 'HADM_ID', how='left')
#mrg20.count()

# %%
mrg18.dtypes
# Out:
# SUBJECT_ID                int64
# HADM_ID                   int64
# ETHNICITY                object
# ADMISSION_TYPE           object
# ADMISSION_LOCATION       object
# INSURANCE                object
# DIAGNOSIS                object
# HOSPITAL_EXPIRE_FLAG    float64
# DISCHARGE_WARDID        float64
# GENDER                   object
# PATIENTWEIGHT           float64
# LOS                     float64
# num_lab_procedures      float64
# num_procedures          float64
# num_medications         float64
# number_diagnoses        float64
# max_glu_serum             int64
# A1Cresult               float64
# Metformin                object
# GlyBURIDE                object
# pioglitazone             object
# dtype: object

# %%
mrg18['HOSPITAL_EXPIRE_FLAG'] = mrg18.HOSPITAL_EXPIRE_FLAG.fillna(0).astype(int)

# %%
mrg18.dtypes
# Out:
# SUBJECT_ID                int64
# HADM_ID                   int64
# ETHNICITY                object
# ADMISSION_TYPE           object
# ADMISSION_LOCATION       object
# INSURANCE                object
# DIAGNOSIS                object
# HOSPITAL_EXPIRE_FLAG      int64
# DISCHARGE_WARDID        float64
# GENDER                   object
# PATIENTWEIGHT           float64
# LOS                     float64
# num_lab_procedures      float64
# num_procedures          float64
# num_medications         float64
# number_diagnoses        float64
# max_glu_serum             int64
# A1Cresult               float64
# Metformin                object
# GlyBURIDE                object
# pioglitazone             object
# dtype: object

# %%
#Moratility count
expire_variable = mrg18.HOSPITAL_EXPIRE_FLAG.value_counts().reset_index(name='Moratility number')
expire_variable
# Out:
#    index  Moratility number
# 0      0           18425663
# 1      1            4346108
